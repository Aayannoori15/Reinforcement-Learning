# %%
import gymnasium as gym 
import numpy as np 
import random

# %%
gamma=0.9
alpha=0.5
epsilon=0.1
episodes=500

# %%
Q=np.zeros((48,4))

# %%
def epsilon_greedy(state):
    if random.random()<epsilon:
        return env.action_space.sample()
    else:
        return np.argmax(Q[state])

# %%
for episode in range(episodes):
    env=gym.make('CliffWalking-v1')
    done=False 
    state,_=env.reset()
    total_reward=0
    episode_len=0
    while not done:
        action=epsilon_greedy(state)
        next_state,reward,terminate,truncate,_=env.step(action)
        done=terminate or truncate 
        Q[state, action] += alpha * (reward + gamma * np.max(Q[next_state]) - Q[state, action])
        state=next_state
        total_reward+=reward 
        episode_len+=1
    print(f'total reward in this episode {episode+1} is {total_reward}')

# %%
env=gym.make('CliffWalking-v1')
done=False 
state,_=env.reset()
total_reward=0
episode_len=0
while not done:
    action=np.argmax(Q[state])
    next_state,reward,terminate,truncate,_=env.step(action)
    done=terminate or truncate 
    state=next_state
    total_reward+=reward 
    episode_len+=1
print(f'total reward in this episode is {total_reward} and episode length is {episode_len}')
